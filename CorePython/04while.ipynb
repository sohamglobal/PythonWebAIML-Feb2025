# %%
n=1
while n>0:
  n=int(input('enter a number '))
  sq=n*n
  print(f'square of {n} is {sq}')
# Out:
# enter a number 12
# square of 12 is 144
# enter a number 54
# square of 54 is 2916
# enter a number 89
# square of 89 is 7921
# enter a number -25
# square of -25 is 625

# %%
nm=''
while nm!='stop':
  nm=input('Enter name ')
  if nm!='stop':
     print(f'welcome {nm}')
# Out:
# Enter name mohammed salah
# welcome mohammed salah
# Enter name bukayo saka
# welcome bukayo saka
# Enter name cole palmer
# welcome cole palmer
# Enter name stop
