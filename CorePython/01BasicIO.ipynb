# %% [markdown]
# # Basic Input Output Notebook

# %% [markdown]
# Take username as input and display welcome message

# %%
nm=input('Enter your name ')
print(f'welcome {nm} to google colab online python')
# Out:
# Enter your name sharayu
# welcome sharayu to google colab online python

# %% [markdown]
# accept a number and display its square

# %%
n=int(input('Enter a number '))
sq=n*n
print(f'square of {n} is {sq}')
# Out:
# Enter a number 13
# square of 13 is 169

# %% [markdown]
# accept 2 float numbers and display their sum

# %%
a=float(input('Enter first number '))
b=float(input('Enter second number '))
c=a+b
print(f'sum of {a} and {b} is {c}')
# Out:
# Enter first number 12
# Enter second number 36.29
# sum of 12.0 and 36.29 is 48.29

# %% [markdown]
# accept purchase amount and display the discount

# %%
amount=float(input('Enter purchase amount '))
discount=amount*10/100
print(f'discount on amount {amount} is {discount}')
# Out:
# Enter purchase amount 12450
# discount on amount 12450.0 is 1245.0

# %% [markdown]
# display electricity bill on the basic of units consumed

# %%
units=int(input('Enter units consumed '))
rate=int(input('Rate per unit '))
bill=units*rate
print(f'Units : {units}')
print(f'Rate : {rate}')
print(f'Bill : Rs. {bill}')
# Out:
# Enter units consumed 237
# Rate per unit 4
# Units : 237
# Rate : 4
# Bill : Rs. 948
